# %%
#Label encoding with IRIS dataset
from sklearn.preprocessing import LabelEncoder 
from pandas import read_csv
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from matplotlib import pyplot 
from xgboost import plot_tree




data = read_csv("iris.csv",header=None)
#data_iris.head()
dataset = data.values
X = dataset[:,:4]
y = dataset[:,4]
# #apply train_test_split
# #encode the y, class values as 
label_encoder = LabelEncoder()
label_encoder = label_encoder.fit(y)
label_encoder_y = label_encoder.transform(y)
# #
seed = 7
test_size = 0.23
X_train,X_test,y_train,y_test = train_test_split(X,label_encoder_y,test_size=test_size,random_state=seed)
# #fit model
model = XGBClassifier()
model.fit(X_train,y_train)
# #predict
#plot tree
predictions = model.predict(X_test)
#print(predictions)
#accuracy
accuracy = accuracy_score(y_test,predictions)
print("Accuracy: %.2f%%" %(accuracy*100))
# Out:
# Accuracy: 85.71%

# %%
plot_tree(model)
pyplot.show()

# %%
from xgboost import plot_importance
plot_importance(model)
pyplot.show()

# %%
print(model.feature_importances_)
#plot
pyplot.bar(range(len(model.feature_importances_)),model.feature_importances_)
pyplot.show()
# Out:
# [0.01607192 0.01623272 0.53223956 0.43545586]
